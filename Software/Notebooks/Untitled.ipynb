# %%
import serial

# %%
ser = serial.Serial('COM4', 9600, timeout=1)

# %%
ser.setDTR(1)

# %%
ser.name
# Out:
# 'COM4'

# %%
ser.write(b'hello')
# Out:
# 5

# %%
ser.isOpen()
# Out:
# True

# %%
from time import sleep
while True:
    print(ser.readline())
    sleep(0.1)
# Out:
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# ...
